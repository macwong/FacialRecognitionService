# %%
# Images obtained from the "Labeled Faces in the Wild" dataset (LFW)
# http://vis-www.cs.umass.edu/lfw/

# %%
import os
from shutil import copyfile

# %%
def create_train_test_data(
    rootdir = '.\data\lfw_aligned',
    trainImageCount = 2,
    testImageCount = 1,
    totalPeople = 100,
    duplicateSingleTrainImage = True):

    totalImageCount = trainImageCount + testImageCount
    newdir = './data/newdir_train' + str(trainImageCount) + '_test' + str(testImageCount) + '_total' + str(totalPeople)
    traindir = newdir + '/train'
    testdir = newdir + '/test'
    directories = os.listdir(rootdir)

    personGroupCount = 0

    print('Check if directory exists...')
    
    if os.path.exists(newdir):
        print("Exists... bombing out")
        return
    else:
        print('Creating directory...')
        os.makedirs(newdir)
        os.makedirs(traindir)
        os.makedirs(testdir)


    print('Iterating through photos')

    for d in directories:    
        subdir = os.path.join(rootdir, d)

        if os.path.isdir(subdir):
            files = os.listdir(subdir)

            if len(files) >= totalImageCount:
                personGroupCount += 1
                print('Found valid PersonGroup:', d)
                fileCount = 0

                for f in files:
                    fileCount += 1
                    
                    fileToCopy = os.path.join(subdir, f)

                    if fileCount == totalImageCount:
                        personGroupTestDir = os.path.join(testdir, d)
                        
                        if not os.path.exists(personGroupTestDir):
                            os.makedirs(personGroupTestDir)
                            
                        copyfile(fileToCopy, os.path.join(personGroupTestDir, f))
                            
                    elif fileCount < totalImageCount:
                        personGroupTrainDir = os.path.join(traindir, d)
                        
                        if not os.path.exists(personGroupTrainDir):
                            os.makedirs(personGroupTrainDir)
                            
                        copyfile(fileToCopy, os.path.join(personGroupTrainDir, f))
                        
                        # If there's only 1 
                        if duplicateSingleTrainImage and trainImageCount == 1:
                            file_name_split = os.path.splitext(f)
                            copyfile(fileToCopy, os.path.join(personGroupTrainDir, file_name_split[0] + "_2." + file_name_split[1]))
                            
                    else:
                        break

                if personGroupCount >= totalPeople:
                    break

    print('Total PersonGroup:', personGroupCount)
    
    return

create_train_test_data(trainImageCount=1, testImageCount = 0, totalPeople = 6000)
# Out:
# Check if directory exists...
# Creating directory...
# Iterating through photos
# Found valid PersonGroup: Aaron_Eckhart
# Found valid PersonGroup: Aaron_Guiel
# Found valid PersonGroup: Aaron_Patterson
# Found valid PersonGroup: Aaron_Peirsol
# Found valid PersonGroup: Aaron_Pena
# Found valid PersonGroup: Aaron_Sorkin
# Found valid PersonGroup: Aaron_Tippin
# Found valid PersonGroup: Abbas_Kiarostami
# Found valid PersonGroup: Abba_Eban
# Found valid PersonGroup: Abdel_Aziz_Al-Hakim
# Found valid PersonGroup: Abdel_Madi_Shabneh
# Found valid PersonGroup: Abdel_Nasser_Assidi
# Found valid PersonGroup: Abdoulaye_Wade
# Found valid PersonGroup: Abdulaziz_Kamilov
# Found valid PersonGroup: Abdullah
# Found valid PersonGroup: Abdullah_Ahmad_Badawi
# Found valid PersonGroup: Abdullah_al-Attiyah
# Found valid PersonGroup: Abdullah_Gul
# Found valid PersonGroup: Abdullah_Nasseef
# Found valid PersonGroup: Abdullatif_Sener
# Found valid PersonGroup: Abdul_Majeed_Shobokshi
# Found valid PersonGroup: Abdul_Rahman
# Found valid PersonGroup: Abel_Aguilar
# Found valid PersonGroup: Abel_Pacheco
# Found valid PersonGroup: Abid_Hamid_Mahmud_Al-Tikriti
# Found valid PersonGroup: Abner_Martinez
# Found valid PersonGroup: Abraham_Foxman
# Found valid PersonGroup: Aby_Har-Even
# Found valid PersonGroup: Adam_Ant
# Found valid PersonGroup: Adam_Freier
# Found valid PersonGroup: Adam_Herbert
# Found valid PersonGroup: Adam_Kennedy
# Found valid PersonGroup: Adam_Mair
# Found valid PersonGroup: Adam_Rich
# Found valid PersonGroup: Adam_Sandler
# Found valid PersonGroup: Adam_Scott
# Found valid PersonGroup: Adelina_Avila
# Found valid PersonGroup: Adel_Al-Jubeir
# Found valid PersonGroup: Adisai_Bodharamik
# Found valid PersonGroup: Adolfo_Aguilar_Zinser
# Found valid PersonGroup: Adolfo_Rodriguez_Saa
# Found valid PersonGroup: Adoor_Gopalakarishnan
# Found valid PersonGroup: Adriana_Lima
# Found valid PersonGroup: Adriana_Perez_Navarro
# Found valid PersonGroup: Adrianna_Zuzic
# Found valid PersonGroup: Adrian_Annus
# Found valid PersonGroup: Adrian_Fernandez
# Found valid PersonGroup: Adrian_McPherson
# Found valid PersonGroup: Adrian_Murrell
# Found valid PersonGroup: Adrian_Nastase
# Found valid PersonGroup: Adrien_Brody
# Found valid PersonGroup: Afton_Smith
# Found valid PersonGroup: Agbani_Darego
# Found valid PersonGroup: Agnelo_Queiroz
# Found valid PersonGroup: Agnes_Bruckner
# Found valid PersonGroup: Ahmad_Jbarah
# Found valid PersonGroup: Ahmad_Masood
# Found valid PersonGroup: Ahmed_Ahmed
# Found valid PersonGroup: Ahmed_Chalabi
# Found valid PersonGroup: Ahmed_Ghazi
# Found valid PersonGroup: Ahmed_Ibrahim_Bilal
# Found valid PersonGroup: Ahmed_Lopez
# Found valid PersonGroup: Ahmed_Qureia
# Found valid PersonGroup: Ahmet_Demir
# Found valid PersonGroup: Ahmet_Necdet_Sezer
# Found valid PersonGroup: Aicha_El_Ouafi
# Found valid PersonGroup: Aidan_Quinn
# Found valid PersonGroup: Aileen_Riggin_Soule
# Found valid PersonGroup: Ainsworth_Dyer
# Found valid PersonGroup: Ain_Seppik
# Found valid PersonGroup: Aishwarya_Rai
# Found valid PersonGroup: Aitor_Gonzalez
# Found valid PersonGroup: Aiysha_Smith
# Found valid PersonGroup: Ai_Sugiyama
# Found valid PersonGroup: Ajit_Agarkar
# Found valid PersonGroup: AJ_Cook
# Found valid PersonGroup: AJ_Lamas
# Found valid PersonGroup: Akbar_Al_Baker
# Found valid PersonGroup: Akbar_Hashemi_Rafsanjani
# Found valid PersonGroup: Akhmed_Zakayev
# Found valid PersonGroup: Akiko_Morigami
# Found valid PersonGroup: Akmal_Taher
# Found valid PersonGroup: Alain_Cervantes
# Found valid PersonGroup: Alain_Ducasse
# Found valid PersonGroup: Alanis_Morissette
# Found valid PersonGroup: Alanna_Ubach
# Found valid PersonGroup: Alan_Ball
# Found valid PersonGroup: Alan_Dershowitz
# Found valid PersonGroup: Alan_Dreher
# Found valid PersonGroup: Alan_Greenspan
# Found valid PersonGroup: Alan_Greer
# Found valid PersonGroup: Alan_Jackson
# Found valid PersonGroup: Alan_Mulally
# Found valid PersonGroup: Alan_Stonecipher
# Found valid PersonGroup: Alan_Tang_Kwong-wing
# Found valid PersonGroup: Alan_Trammell
# Found valid PersonGroup: Alan_Zemaitis
# Found valid PersonGroup: Alastair_Campbell
# Found valid PersonGroup: Alastair_Johnston
# Found valid PersonGroup: Albaro_Recoba
# Found valid PersonGroup: Alberta_Lee
# Found valid PersonGroup: Alberto_Acosta
# Found valid PersonGroup: Alberto_Fujimori
# Found valid PersonGroup: Alberto_Gonzales
# Found valid PersonGroup: Alberto_Ruiz_Gallardon
# Found valid PersonGroup: Alberto_Sordi
# Found valid PersonGroup: Albert_Brooks
# Found valid PersonGroup: Albert_Costa
# Found valid PersonGroup: Albert_Montanes
# Found valid PersonGroup: Albert_Pujols
# Found valid PersonGroup: Albrecht_Mentz
# Found valid PersonGroup: Aldo_Paredes
# Found valid PersonGroup: Alecos_Markides
# Found valid PersonGroup: Alec_Baldwin
# Found valid PersonGroup: Alejandro_Atchugarry
# Found valid PersonGroup: Alejandro_Avila
# Found valid PersonGroup: Alejandro_Fernandez
# Found valid PersonGroup: Alejandro_Gonzalez_Inarritu
# Found valid PersonGroup: Alejandro_Lembo
# Found valid PersonGroup: Alejandro_Lerner
# Found valid PersonGroup: Alejandro_Lopez
# Found valid PersonGroup: Alejandro_Toledo
# Found valid PersonGroup: Aleksander_Kwasniewski
# Found valid PersonGroup: Aleksander_Voloshin
# Found valid PersonGroup: Alek_Wek
# Found valid PersonGroup: Alessandra_Cerna
# Found valid PersonGroup: Alessandro_Nesta
# Found valid PersonGroup: Alexander_Downer
# Found valid PersonGroup: Alexander_Losyukov
# Found valid PersonGroup: Alexander_Lukashenko
# Found valid PersonGroup: Alexander_Payne
# Found valid PersonGroup: Alexander_Rumyantsev
# Found valid PersonGroup: Alexandra_Jackson
# Found valid PersonGroup: Alexandra_Pelosi
# Found valid PersonGroup: Alexandra_Rozovskaya
# Found valid PersonGroup: Alexandra_Spann
# Found valid PersonGroup: Alexandra_Stevenson
# Found valid PersonGroup: Alexandra_Vodjanikova
# Found valid PersonGroup: Alexandre_Daigle
# Found valid PersonGroup: Alexandre_Despatie
# Found valid PersonGroup: Alexandre_Herchcovitch
# Found valid PersonGroup: Alexandre_Vinokourov
# Found valid PersonGroup: Alexa_Loren
# Found valid PersonGroup: Alexa_Vega
# Found valid PersonGroup: Alexis_Bledel
# Found valid PersonGroup: Alexis_Dennisoff
# Found valid PersonGroup: Alex_Barros
# Found valid PersonGroup: Alex_Cabrera
# Found valid PersonGroup: Alex_Cejka
# Found valid PersonGroup: Alex_Corretja
# Found valid PersonGroup: Alex_Ferguson
# Found valid PersonGroup: Alex_Gonzalez
# Found valid PersonGroup: Alex_Holmes
# Found valid PersonGroup: Alex_King
# Found valid PersonGroup: Alex_Penelas
# Found valid PersonGroup: Alex_Popov
# Found valid PersonGroup: Alex_Sink
# Found valid PersonGroup: Alex_Wallau
# Found valid PersonGroup: Alex_Zanardi
# Found valid PersonGroup: Alfonso_Cuaron
# Found valid PersonGroup: Alfonso_Portillo
# Found valid PersonGroup: Alfonso_Soriano
# Found valid PersonGroup: Alfredo_di_Stefano
# Found valid PersonGroup: Alfredo_Moreno
# Found valid PersonGroup: Alfredo_Pena
# Found valid PersonGroup: Alfred_Ford
# Found valid PersonGroup: Alfred_Sant
# Found valid PersonGroup: Alice_Fisher
# Found valid PersonGroup: Alicia_Hollowell
# Found valid PersonGroup: Alicia_Keys
# Found valid PersonGroup: Alicia_Molik
# Found valid PersonGroup: Alicia_Silverstone
# Found valid PersonGroup: Alicia_Witt
# Found valid PersonGroup: Alimzhan_Tokhtakhounov
# Found valid PersonGroup: Alina_Kabaeva
# Found valid PersonGroup: Aline_Chretien
# Found valid PersonGroup: Alisha_Richman
# Found valid PersonGroup: Alison_Krauss
# Found valid PersonGroup: Alison_Lohman
# Found valid PersonGroup: Alistair_MacDonald
# Found valid PersonGroup: Ali_Abbas
# Found valid PersonGroup: Ali_Abdullah_Saleh
# Found valid PersonGroup: Ali_Adbul_Karim_Madani
# Found valid PersonGroup: Ali_Ahmeti
# Found valid PersonGroup: Ali_Bin_Hussein
# Found valid PersonGroup: Ali_Fallahian
# Found valid PersonGroup: Ali_Hammoud
# Found valid PersonGroup: Ali_Khamenei
# Found valid PersonGroup: Ali_Mohammed_Maher
# Found valid PersonGroup: Ali_Naimi
# Found valid PersonGroup: Allan_Houston
# Found valid PersonGroup: Allan_Kemakeza
# Found valid PersonGroup: Allan_Wagner
# Found valid PersonGroup: Allen_Iverson
# Found valid PersonGroup: Allen_Rock
# Found valid PersonGroup: Allison_Janney
# Found valid PersonGroup: Allison_Searing
# Found valid PersonGroup: Allyson_Felix
# Found valid PersonGroup: Ally_Sheedy
# Found valid PersonGroup: Alma_Powell
# Found valid PersonGroup: Almeida_Baptista
# Found valid PersonGroup: Alonzo_Mourning
# Found valid PersonGroup: Alvaro_Noboa
# Found valid PersonGroup: Alvaro_Silva_Calderon
# Found valid PersonGroup: Alvaro_Uribe
# Found valid PersonGroup: Alyse_Beaupre
# Found valid PersonGroup: Alyson_Hannigan
# Found valid PersonGroup: Aly_Wagner
# Found valid PersonGroup: Al_Cardenas
# Found valid PersonGroup: Al_Davis
# Found valid PersonGroup: Al_Gore
# Found valid PersonGroup: Al_Leiter
# Found valid PersonGroup: Al_Pacino
# Found valid PersonGroup: Al_Sharpton
# Found valid PersonGroup: Amanda_Beard
# Found valid PersonGroup: Amanda_Bynes
# Found valid PersonGroup: Amanda_Coetzer
# Found valid PersonGroup: Amanda_Marsh
# Found valid PersonGroup: Amanda_Plumer
# Found valid PersonGroup: Amber_Frey
# Found valid PersonGroup: Amber_Tamblyn
# Found valid PersonGroup: Ambrose_Lee
# Found valid PersonGroup: Amelia_Vega
# Found valid PersonGroup: Amelie_Mauresmo
# Found valid PersonGroup: Amer_al-Saadi
# Found valid PersonGroup: Amporn_Falise
# Found valid PersonGroup: Amram_Mitzna
# Found valid PersonGroup: Amr_Moussa
# Found valid PersonGroup: Amy_Brenneman
# Found valid PersonGroup: Amy_Cotton
# Found valid PersonGroup: Amy_Gale
# Found valid PersonGroup: Amy_Pascal
# Found valid PersonGroup: Amy_Redford
# Found valid PersonGroup: Amy_Smart
# Found valid PersonGroup: Amy_Yasbeck
# Found valid PersonGroup: Anastasia_Kelesidou
# Found valid PersonGroup: Anastasia_Myskina
# Found valid PersonGroup: Anatoliy_Kinakh
# Found valid PersonGroup: Ana_Claudia_Talancon
# Found valid PersonGroup: Ana_Guevara
# Found valid PersonGroup: Ana_Isabel_Sanchez
# Found valid PersonGroup: Ana_Palacio
# Found valid PersonGroup: Ana_Paula_Gerard
# Found valid PersonGroup: Ana_Sebastiao
# Found valid PersonGroup: Anderson_Varejao
# Found valid PersonGroup: Anders_Ebbeson
# Found valid PersonGroup: Anders_Fogh_Rasmussen
# Found valid PersonGroup: Andreas_Vinciguerra
# Found valid PersonGroup: Andrea_Bocelli
# Found valid PersonGroup: Andrea_De_Cruz
# Found valid PersonGroup: Andrea_Kiser
# Found valid PersonGroup: Andrea_Yates
# Found valid PersonGroup: Andrei_Konchalovsky
# Found valid PersonGroup: Andrei_Mikhnevich
# Found valid PersonGroup: Andrei_Nikolishin
# Found valid PersonGroup: Andres_DAlessandro
# Found valid PersonGroup: Andres_Manuel_Lopez_Obrador
# Found valid PersonGroup: Andres_Pastrana
# Found valid PersonGroup: Andrew_Bernard
# Found valid PersonGroup: Andrew_Bunner
# Found valid PersonGroup: Andrew_Caldecott
# Found valid PersonGroup: Andrew_Cuomo
# Found valid PersonGroup: Andrew_Fastow
# Found valid PersonGroup: Andrew_Firestone
# Found valid PersonGroup: Andrew_Gilligan
# Found valid PersonGroup: Andrew_Jarecki
# Found valid PersonGroup: Andrew_Luster
# Found valid PersonGroup: Andrew_Niccol
# Found valid PersonGroup: Andrew_Sabey
# Found valid PersonGroup: Andrew_Shutley
# Found valid PersonGroup: Andrew_Weissmann
# Found valid PersonGroup: Andrew_Wetzler
# Found valid PersonGroup: Andre_Agassi
# Found valid PersonGroup: Andre_Bucher
# Found valid PersonGroup: Andre_Lange
# Found valid PersonGroup: Andre_Smith
# Found valid PersonGroup: Andre_Techine
# Found valid PersonGroup: Andrzej_Tyszkiewicz
# Found valid PersonGroup: Andy_Benes
# Found valid PersonGroup: Andy_Bryant
# Found valid PersonGroup: Andy_Dick
# Found valid PersonGroup: Andy_Garcia
# Found valid PersonGroup: Andy_Graves
# Found valid PersonGroup: Andy_Griffith
# Found valid PersonGroup: Andy_Griggs
# Found valid PersonGroup: Andy_Hebb
# Found valid PersonGroup: Andy_Lau
# Found valid PersonGroup: Andy_Madikians
# Found valid PersonGroup: Andy_North
# Found valid PersonGroup: Andy_Perez
# Found valid PersonGroup: Andy_Roddick
# Found valid PersonGroup: Andy_Rooney
# Found valid PersonGroup: Andy_Warhol
# Found valid PersonGroup: Andy_Wisecarver
# Found valid PersonGroup: Anette_Hosoi
# Found valid PersonGroup: AnFernce_Negron
# Found valid PersonGroup: Angela_Alvarado_Rosa
# Found valid PersonGroup: Angela_Bassett
# Found valid PersonGroup: Angela_Lansbury
# Found valid PersonGroup: Angela_Mascia-Frye
# Found valid PersonGroup: Angela_Merkel
# Found valid PersonGroup: Angelica_Romero
# Found valid PersonGroup: Angelina_Jolie
# Found valid PersonGroup: Angelo_Genova
# Found valid PersonGroup: Angelo_Reyes
# Found valid PersonGroup: Angel_Lockward
# Found valid PersonGroup: Angel_Maza
# Found valid PersonGroup: Angie_Arzola
# Found valid PersonGroup: Angie_Martinez
# Found valid PersonGroup: Anibal_Ibarra
# Found valid PersonGroup: Anil_Ramsook
# Found valid PersonGroup: Anita_DeFrantz
# Found valid PersonGroup: Anja_Paerson
# Found valid PersonGroup: Anjum_Hussain
# Found valid PersonGroup: Anna_Chicherova
# Found valid PersonGroup: Anna_Faris
# Found valid PersonGroup: Anna_Jones
# Found valid PersonGroup: Anna_Kournikova
# Found valid PersonGroup: Anna_Nicole_Smith
# Found valid PersonGroup: Anneli_Jaatteenmaki
# Found valid PersonGroup: Annette_Bening
# Found valid PersonGroup: Annette_Lu
# Found valid PersonGroup: Anne_Cavers
# Found valid PersonGroup: Anne_Donovan
# Found valid PersonGroup: Anne_Heche
# Found valid PersonGroup: Anne_Krueger
# Found valid PersonGroup: Anne_McLellan
# Found valid PersonGroup: Anne_ONeil
# Found valid PersonGroup: Annie-Jeanne_Reynaud
# Found valid PersonGroup: Annie_Chaplin
# Found valid PersonGroup: Annie_Machon
# Found valid PersonGroup: Annika_Sorenstam
# Found valid PersonGroup: Ann_Godbehere
# Found valid PersonGroup: Ann_Landers
# Found valid PersonGroup: Ann_Morgan
# Found valid PersonGroup: Ann_Veneman
# Found valid PersonGroup: Antanas_Valionis
# Found valid PersonGroup: Anthony_Carter
# Found valid PersonGroup: Anthony_Corso
# Found valid PersonGroup: Anthony_Ervin
# Found valid PersonGroup: Anthony_Fauci
# Found valid PersonGroup: Anthony_Garotinho
# Found valid PersonGroup: Anthony_Hazen
# Found valid PersonGroup: Anthony_Hopkins
# Found valid PersonGroup: Anthony_LaPaglia
# Found valid PersonGroup: Anthony_Lee_Johnson
# Found valid PersonGroup: Anthony_Mazur
# Found valid PersonGroup: Anthony_Pico
# Found valid PersonGroup: Anthony_Pisciotti
# Found valid PersonGroup: Anthony_Principi
# Found valid PersonGroup: Anthony_Rackauckas
# Found valid PersonGroup: Anthony_Scott_Miller
# Found valid PersonGroup: Antje_Buschschulte
# Found valid PersonGroup: Antonio_Banderas
# Found valid PersonGroup: Antonio_Bernardo
# Found valid PersonGroup: Antonio_Cassano
# Found valid PersonGroup: Antonio_Catania
# Found valid PersonGroup: Antonio_Elias_Saca
# Found valid PersonGroup: Antonio_Palocci
# Found valid PersonGroup: Antonio_Trillanes
# Found valid PersonGroup: Antony_Leung
# Found valid PersonGroup: Anton_Balasingham
# Found valid PersonGroup: Antwun_Echols
# Found valid PersonGroup: Anwar_Ibrahim
# Found valid PersonGroup: Anzori_Kikalishvili
# Found valid PersonGroup: Aparna_Pillai
# Found valid PersonGroup: Aram_Adler
# Found valid PersonGroup: Arantxa_Sanchez-Vicario
# Found valid PersonGroup: Aretha_Franklin
# Found valid PersonGroup: Arianna_Huffington
# Found valid PersonGroup: Ariel_Sharon
# Found valid PersonGroup: Arie_Haan
# Found valid PersonGroup: Arif_Mardin
# Found valid PersonGroup: Ari_Bousbib
# Found valid PersonGroup: Ari_Fleischer
# Found valid PersonGroup: Arlen_Specter
# Found valid PersonGroup: Armando_Avila_Panchame
# Found valid PersonGroup: Armando_Calderon_Sol
# Found valid PersonGroup: Armando_Carrillo
# Found valid PersonGroup: Armand_Sargen
# Found valid PersonGroup: Arminio_Fraga
# Found valid PersonGroup: Arnaud_Clement
# Found valid PersonGroup: Arnaud_Lagardere
# Found valid PersonGroup: Arnie_Boehm
# Found valid PersonGroup: Arnoldo_Aleman
# Found valid PersonGroup: Arnold_Palmer
# Found valid PersonGroup: Arnold_Schwarzenegger
# Found valid PersonGroup: Arnold_Scott
# Found valid PersonGroup: Aron_Ralston
# Found valid PersonGroup: Arsinee_Khanjian
# Found valid PersonGroup: Arthur_Johnson
# Found valid PersonGroup: Arthur_Martinez
# Found valid PersonGroup: Artieas_Shanks
# Found valid PersonGroup: Arturo_Gatti
# Found valid PersonGroup: Art_Cooper
# Found valid PersonGroup: Art_Hoffmann
# Found valid PersonGroup: Art_Howe
# Found valid PersonGroup: Art_Lopez
# Found valid PersonGroup: Arye_Mekel
# Found valid PersonGroup: Asa_Hutchinson
# Found valid PersonGroup: Ascencion_Barajas
# Found valid PersonGroup: Ashanti
# Found valid PersonGroup: Ashlea_Talbot
# Found valid PersonGroup: Ashley_Judd
# Found valid PersonGroup: Ashley_Olsen
# Found valid PersonGroup: Ashley_Postell
# Found valid PersonGroup: Ashraf_Alasmar
# Found valid PersonGroup: Ashraf_Ghani
# Found valid PersonGroup: Ashton_Kutcher
# Found valid PersonGroup: Asif_Ali_Zardari
# Found valid PersonGroup: Asif_Hanif
# Found valid PersonGroup: Askar_Akayev
# Found valid PersonGroup: Asmaa_Assad
# Found valid PersonGroup: Assad_Ahmadi
# Found valid PersonGroup: Astou_Ndiaye-Diatta
# Found valid PersonGroup: Astrid_Betancourt
# Found valid PersonGroup: Astrid_Eyzaguirre
# Found valid PersonGroup: Atal_Bihari_Vajpayee
# Found valid PersonGroup: Ataollah_Mohajerani
# Found valid PersonGroup: Atiabet_Ijan_Amabel
# Found valid PersonGroup: Atom_Egoyan
# Found valid PersonGroup: Atsushi_Sato
# Found valid PersonGroup: Audrey_Lacroix
# Found valid PersonGroup: Audrey_Sauret
# Found valid PersonGroup: Augustin_Calleri
# Found valid PersonGroup: Augusto_Pinochet
# Found valid PersonGroup: Augusto_Roa_Bastos
# Found valid PersonGroup: Aung_San_Suu_Kyi
# Found valid PersonGroup: Austin_Kearns
# Found valid PersonGroup: Avril_Lavigne
# Found valid PersonGroup: Azmi_Bishara
# Found valid PersonGroup: Azra_Akin
# Found valid PersonGroup: Babe_Ruth
# Found valid PersonGroup: Baburam_Bhattari
# Found valid PersonGroup: Bak_Chang-Ryun
# Found valid PersonGroup: Barbara_Bach
# Found valid PersonGroup: Barbara_Becker
# Found valid PersonGroup: Barbara_Bodine
# Found valid PersonGroup: Barbara_Boxer
# Found valid PersonGroup: Barbara_Brezigar
# Found valid PersonGroup: Barbara_De_Brun
# Found valid PersonGroup: Barbara_Esbin
# Found valid PersonGroup: Barbara_Felt-Miller
# Found valid PersonGroup: Barbara_Roberts
# Found valid PersonGroup: Barbara_Walters
# Found valid PersonGroup: Barbora_Strycova
# Found valid PersonGroup: Barbra_Streisand
# Found valid PersonGroup: Barrett_Jackman
# Found valid PersonGroup: Barry_Alvarez
# Found valid PersonGroup: Barry_Bonds
# Found valid PersonGroup: Barry_Collier
# Found valid PersonGroup: Barry_Diller
# Found valid PersonGroup: Barry_Ford
# Found valid PersonGroup: Barry_Hinson
# Found valid PersonGroup: Barry_Nakell
# Found valid PersonGroup: Barry_Switzer
# Found valid PersonGroup: Barry_Williams
# Found valid PersonGroup: Barry_Zito
# Found valid PersonGroup: Bartosz_Kizierowski
# Found valid PersonGroup: Bart_Freundlich
# Found valid PersonGroup: Bart_Hendricks
# Found valid PersonGroup: Barzan_al-Tikriti
# Found valid PersonGroup: Basdeo_Panday
# Found valid PersonGroup: Bashar_Assad
# Found valid PersonGroup: Baz_Luhrmann
# Found valid PersonGroup: BB_King
# Found valid PersonGroup: Beatrice_Dalle
# Found valid PersonGroup: Beatriz_Merino
# Found valid PersonGroup: Beecher_Ray_Kirby
# Found valid PersonGroup: Begum_Khaleda_Zia
# Found valid PersonGroup: Bela_Karolyi
# Found valid PersonGroup: Benazir_Bhutto
# Found valid PersonGroup: Benedita_da_Silva
# Found valid PersonGroup: Benicio_Del_Toro
# Found valid PersonGroup: Benito_Santiago
# Found valid PersonGroup: Benjamin_Bratt
# Found valid PersonGroup: Benjamin_Franklin
# Found valid PersonGroup: Benjamin_Martinez
# Found valid PersonGroup: Benjamin_McKenzie
# Found valid PersonGroup: Benjamin_Netanyahu
# Found valid PersonGroup: Benjamin_Neulander
# Found valid PersonGroup: Ben_Affleck
# Found valid PersonGroup: Ben_Betts
# Found valid PersonGroup: Ben_Braun
# Found valid PersonGroup: Ben_Broussard
# Found valid PersonGroup: Ben_Cahoon
# Found valid PersonGroup: Ben_Chandler
# Found valid PersonGroup: Ben_Cohen
# Found valid PersonGroup: Ben_Curtis
# Found valid PersonGroup: Ben_Davis
# Found valid PersonGroup: Ben_Glisan
# Found valid PersonGroup: Ben_Howland
# Found valid PersonGroup: Ben_Kingsley
# Found valid PersonGroup: Ben_Lee
# Found valid PersonGroup: Ben_Stein
# Found valid PersonGroup: Ben_Wallace
# Found valid PersonGroup: Bernadette_Peters
# Found valid PersonGroup: Bernardo_Segura
# Found valid PersonGroup: Bernard_Ebbers
# Found valid PersonGroup: Bernard_Giraudeau
# Found valid PersonGroup: Bernard_Kerik
# Found valid PersonGroup: Bernard_Landry
# Found valid PersonGroup: Bernard_Law
# Found valid PersonGroup: Bernard_Lord
# Found valid PersonGroup: Bernard_Siegel
# Found valid PersonGroup: Bernice_Wong
# Found valid PersonGroup: Bertie_Ahern
# Found valid PersonGroup: Bertrand_Bonello
# Found valid PersonGroup: Bertrand_Delanoe
# Found valid PersonGroup: Beth_Blough
# Found valid PersonGroup: Beth_Jones
# Found valid PersonGroup: Betsy_Coffin
# Found valid PersonGroup: Betsy_Smith
# Found valid PersonGroup: Bettina_Rheims
# Found valid PersonGroup: Betty_Garrison
# Found valid PersonGroup: Betty_Williams
# Found valid PersonGroup: Beyonce_Knowles
# Found valid PersonGroup: Bianca_Jagger
# Found valid PersonGroup: Bijan_Darvish
# Found valid PersonGroup: Bijan_Namdar_Zangeneh
# Found valid PersonGroup: Bilal_Erdogan
# Found valid PersonGroup: Biljana_Plavsic
# Found valid PersonGroup: Billy_Andrade
# Found valid PersonGroup: Billy_Beane
# Found valid PersonGroup: Billy_Bob_Thornton
# Found valid PersonGroup: Billy_Boyd
# Found valid PersonGroup: Billy_Crawford
# Found valid PersonGroup: Billy_Crystal
# Found valid PersonGroup: Billy_Donovan
# Found valid PersonGroup: Billy_Edelin
# Found valid PersonGroup: Billy_Gilman
# Found valid PersonGroup: Billy_Graham
# Found valid PersonGroup: Billy_Joel
# Found valid PersonGroup: Billy_Rork
# Found valid PersonGroup: Billy_Sollie
# Found valid PersonGroup: Billy_Tibbets
# Found valid PersonGroup: Bill_Belichick
# Found valid PersonGroup: Bill_Bradley
# Found valid PersonGroup: Bill_Butler
# Found valid PersonGroup: Bill_Byrne
# Found valid PersonGroup: Bill_Callahan
# Found valid PersonGroup: Bill_Carmody
# Found valid PersonGroup: Bill_Cartwright
# Found valid PersonGroup: Bill_Clancy
# Found valid PersonGroup: Bill_Clinton
# Found valid PersonGroup: Bill_Curry
# Found valid PersonGroup: Bill_Doba
# Found valid PersonGroup: Bill_Duffey
# Found valid PersonGroup: Bill_Elliott
# Found valid PersonGroup: Bill_Fennelly
# Found valid PersonGroup: Bill_Frist
# Found valid PersonGroup: Bill_Gates
# Found valid PersonGroup: Bill_Graham
# Found valid PersonGroup: Bill_Guerin
# Found valid PersonGroup: Bill_Herrion
# Found valid PersonGroup: Bill_Hughes
# Found valid PersonGroup: Bill_King
# Found valid PersonGroup: Bill_Kollar
# Found valid PersonGroup: Bill_Kong
# Found valid PersonGroup: Bill_Lerach
# Found valid PersonGroup: Bill_Maher
# Found valid PersonGroup: Bill_Mauldin
# Found valid PersonGroup: Bill_McBride
# Found valid PersonGroup: Bill_Nelson
# Found valid PersonGroup: Bill_OReilly
# Found valid PersonGroup: Bill_Parcells
# Found valid PersonGroup: Bill_Parsons
# Found valid PersonGroup: Bill_Paxton
# Found valid PersonGroup: Bill_Pryor
# Found valid PersonGroup: Bill_Rainer
# Found valid PersonGroup: Bill_Readdy
# Found valid PersonGroup: Bill_Richardson
# Found valid PersonGroup: Bill_Self
# Found valid PersonGroup: Bill_Simon
# Found valid PersonGroup: Bill_Sizemore
# Found valid PersonGroup: Bill_Stapleton
# Found valid PersonGroup: Bill_Stein
# Found valid PersonGroup: Bill_Walton
# Found valid PersonGroup: Bing_Crosby
# Found valid PersonGroup: Binyamin_Ben-Eliezer
# Found valid PersonGroup: Bison_Dele
# Found valid PersonGroup: Bixente_LIzarazu
# Found valid PersonGroup: BJ_Habibie
# Found valid PersonGroup: Blas_Ople
# Found valid PersonGroup: Blythe_Danner
# Found valid PersonGroup: Blythe_Hartley
# Found valid PersonGroup: Bobby_Bowden
# Found valid PersonGroup: Bobby_Goldwater
# Found valid PersonGroup: Bobby_Jackson
# Found valid PersonGroup: Bobby_Kielty
# Found valid PersonGroup: Bobby_Robson
# Found valid PersonGroup: Bobo_Balde
# Found valid PersonGroup: Bob_Alper
# Found valid PersonGroup: Bob_Beauprez
# Found valid PersonGroup: Bob_Bowlsby
# Found valid PersonGroup: Bob_Cantrell
# Found valid PersonGroup: Bob_Colvin
# Found valid PersonGroup: Bob_Crippen
# Found valid PersonGroup: Bob_Curtis
# Found valid PersonGroup: Bob_Dole
# Found valid PersonGroup: Bob_Eskridge
# Found valid PersonGroup: Bob_Ferguson
# Found valid PersonGroup: Bob_Geldof
# Found valid PersonGroup: Bob_Goldman
# Found valid PersonGroup: Bob_Graham
# Found valid PersonGroup: Bob_Guccione
# Found valid PersonGroup: Bob_Hartley
# Found valid PersonGroup: Bob_Hayes
# Found valid PersonGroup: Bob_Herz
# Found valid PersonGroup: Bob_Holden
# Found valid PersonGroup: Bob_Hope
# Found valid PersonGroup: Bob_Huggins
# Found valid PersonGroup: Bob_Iger
# Found valid PersonGroup: Bob_Krueger
# Found valid PersonGroup: Bob_Melvin
# Found valid PersonGroup: Bob_Menendez
# Found valid PersonGroup: Bob_Newhart
# Found valid PersonGroup: Bob_Petrino
# Found valid PersonGroup: Bob_Riley
# Found valid PersonGroup: Bob_Stoops
# Found valid PersonGroup: Bob_Sulkin
# Found valid PersonGroup: Bob_Taft
# Found valid PersonGroup: Bob_Wright
# Found valid PersonGroup: Bode_Miller
# Found valid PersonGroup: Bonnie_Fuller
# Found valid PersonGroup: Bonnie_Hunt
# Found valid PersonGroup: Bono
# Found valid PersonGroup: Boris_Becker
# Found valid PersonGroup: Boris_Berezovsky
# Found valid PersonGroup: Boris_Henry
# Found valid PersonGroup: Boris_Jordan
# Found valid PersonGroup: Boris_Trajkovski
# Found valid PersonGroup: Boris_Yeltsin
# Found valid PersonGroup: Boutros_Boutros_Ghali
# Found valid PersonGroup: Bo_Pelini
# Found valid PersonGroup: Bo_Ryan
# Found valid PersonGroup: Brady_Rodgers
# Found valid PersonGroup: Brad_Alexander_Smith
# Found valid PersonGroup: Brad_Banks
# Found valid PersonGroup: Brad_Brownell
# Found valid PersonGroup: Brad_Garrett
# Found valid PersonGroup: Brad_Gushue
# Found valid PersonGroup: Brad_Johnson
# Found valid PersonGroup: Brad_Miller
# Found valid PersonGroup: Brad_Pitt
# Found valid PersonGroup: Brad_Russ
# Found valid PersonGroup: Brad_Smith
# Found valid PersonGroup: Brad_Wilk
# Found valid PersonGroup: Brajesh_Mishra
# Found valid PersonGroup: Brandon_Boyd
# Found valid PersonGroup: Brandon_Fails
# Found valid PersonGroup: Brandon_Hammond
# Found valid PersonGroup: Brandon_Inge
# Found valid PersonGroup: Brandon_Jones
# Found valid PersonGroup: Brandon_Knight
# Found valid PersonGroup: Brandon_Larson
# Found valid PersonGroup: Brandon_Lloyd
# Found valid PersonGroup: Brandon_Robinson
# Found valid PersonGroup: Brandon_Spann
# Found valid PersonGroup: Brandon_Webb
# Found valid PersonGroup: Branko_Crvenkovski
# Found valid PersonGroup: Brawley_King
# Found valid PersonGroup: Brendan_Fraser
# Found valid PersonGroup: Brendan_Gaughan
# Found valid PersonGroup: Brendan_Hansen
# Found valid PersonGroup: Brendan_Stai
# Found valid PersonGroup: Brenda_Magana
# Found valid PersonGroup: Brenda_van_Dam
# Found valid PersonGroup: Brenda_Wilson
# Found valid PersonGroup: Brennon_Leighton
# Found valid PersonGroup: Brent_Coles
# Found valid PersonGroup: Brett_Boone
# Found valid PersonGroup: Brett_Hawke
# Found valid PersonGroup: Brett_Hull
# Found valid PersonGroup: Brett_Perry
# Found valid PersonGroup: Brian_Billick
# Found valid PersonGroup: Brian_Campbell
# Found valid PersonGroup: Brian_Cashman
# Found valid PersonGroup: Brian_Clemens
# Found valid PersonGroup: Brian_Cook
# Found valid PersonGroup: Brian_Cowen
# Found valid PersonGroup: Brian_De_Palma
# Found valid PersonGroup: Brian_Florence
# Found valid PersonGroup: Brian_Grazier
# Found valid PersonGroup: Brian_Gregory
# Found valid PersonGroup: Brian_Griese
# Found valid PersonGroup: Brian_Heidik
# Found valid PersonGroup: Brian_Henson
# Found valid PersonGroup: Brian_Jordan
# Found valid PersonGroup: Brian_Kerr
# Found valid PersonGroup: Brian_Lara
# Found valid PersonGroup: Brian_McIntyre
# Found valid PersonGroup: Brian_Meadors
# Found valid PersonGroup: Brian_Mulroney
# Found valid PersonGroup: Brian_Olson
# Found valid PersonGroup: Brian_Pavlich
# Found valid PersonGroup: Brian_Scalabrine
# Found valid PersonGroup: Brian_Schneider
# Found valid PersonGroup: Brian_StPierre
# Found valid PersonGroup: Brian_Van_Dusen
# Found valid PersonGroup: Brian_Weaver
# Found valid PersonGroup: Brian_Wells
# Found valid PersonGroup: Brian_Williams
# Found valid PersonGroup: Bridgette_Wilson-Sampras
# Found valid PersonGroup: Bridget_Fonda
# Found valid PersonGroup: Brigitte_Boisselier
# Found valid PersonGroup: Britney_Spears
# Found valid PersonGroup: Brittany_Snow
# Found valid PersonGroup: Brock_Berlin
# Found valid PersonGroup: Bronson_Arroyo
# Found valid PersonGroup: Brooke_Adams
# Found valid PersonGroup: Brooke_Gordon
# Found valid PersonGroup: Brooke_Shields
# Found valid PersonGroup: Brook_Robinson
# Found valid PersonGroup: Bruce_Arena
# Found valid PersonGroup: Bruce_Gebhardt
# Found valid PersonGroup: Bruce_Lunsford
# Found valid PersonGroup: Bruce_Paltrow
# Found valid PersonGroup: Bruce_Springsteen
# Found valid PersonGroup: Bruce_Van_De_Velde
# Found valid PersonGroup: Bruce_Weber
# Found valid PersonGroup: Bruce_Willis
# Found valid PersonGroup: Bruna_Colosio
# Found valid PersonGroup: Bruno_Junquiera
# Found valid PersonGroup: Bryant_Young
# Found valid PersonGroup: Bryan_Adams
# Found valid PersonGroup: Bryan_Chui
# Found valid PersonGroup: Bryan_Cooley
# Found valid PersonGroup: Bryan_Murray
# Found valid PersonGroup: Bryan_Thomas
# Found valid PersonGroup: Bryce_Carmine
# Found valid PersonGroup: Buck_Rodgers
# Found valid PersonGroup: Buddy_Ryan
# Found valid PersonGroup: Budd_Schulberg
# Found valid PersonGroup: Bud_Selig
# Found valid PersonGroup: Buford_Blount
# Found valid PersonGroup: Bulent_Ecevit
# Found valid PersonGroup: Bustam_A_Zedan_Aljanabi
# Found valid PersonGroup: Butch_Davis
# Found valid PersonGroup: Buzz_Hargrove
# Found valid PersonGroup: Byron_Scott
# Found valid PersonGroup: Cabas
# Found valid PersonGroup: Caio_Blat
# Found valid PersonGroup: Calbert_Cheaney
# Found valid PersonGroup: Calista_Flockhart
# Found valid PersonGroup: Calvin_Harrison
# Found valid PersonGroup: Calvin_Joseph_Coleman
# Found valid PersonGroup: Cameron_Diaz
# Found valid PersonGroup: Camilla_Parker_Bowles
# Found valid PersonGroup: Camille_Colvin
# Found valid PersonGroup: Camille_Lewis
# Found valid PersonGroup: Camryn_Manheim
# Found valid PersonGroup: Candace_Sutton
# Found valid PersonGroup: Candice_Beatty
# Found valid PersonGroup: Candice_Bergen
# Found valid PersonGroup: Candie_Kung
# Found valid PersonGroup: Carey_Lowell
# Found valid PersonGroup: Carina_Lau_Ka-ling
# Found valid PersonGroup: Carin_Koch
# Found valid PersonGroup: Cari_Davis
# Found valid PersonGroup: Carla_Del_Ponte
# Found valid PersonGroup: Carla_Gay_Balingit
# Found valid PersonGroup: Carla_Gugino
# Found valid PersonGroup: Carla_Moreno
# Found valid PersonGroup: Carla_Myers
# Found valid PersonGroup: Carla_Sullivan
# Found valid PersonGroup: Carla_Tricoli
# Found valid PersonGroup: Carlos_Alberto
# Found valid PersonGroup: Carlos_Alberto_Parreira
# Found valid PersonGroup: Carlos_Arroyo
# Found valid PersonGroup: Carlos_Barra
# Found valid PersonGroup: Carlos_Barragan
# Found valid PersonGroup: Carlos_Beltran
# Found valid PersonGroup: Carlos_Bianchi
# Found valid PersonGroup: Carlos_De_Abreu
# Found valid PersonGroup: Carlos_Fasciolo
# Found valid PersonGroup: Carlos_Ghosn
# Found valid PersonGroup: Carlos_Iturgaitz
# Found valid PersonGroup: Carlos_Juarez
# Found valid PersonGroup: Carlos_Lordkipanitse
# Found valid PersonGroup: Carlos_Manuel_Pruneda
# Found valid PersonGroup: Carlos_Menem
# Found valid PersonGroup: Carlos_Mesa
# Found valid PersonGroup: Carlos_Moya
# Found valid PersonGroup: Carlos_Ortega
# Found valid PersonGroup: Carlos_Paternina
# Found valid PersonGroup: Carlos_Queiroz
# Found valid PersonGroup: Carlos_Quintanilla_Schmidt
# Found valid PersonGroup: Carlos_Ruckauf
# Found valid PersonGroup: Carlos_Ruiz
# Found valid PersonGroup: Carlos_Salinas
# Found valid PersonGroup: Carlos_Savedra
# Found valid PersonGroup: Carlos_Vives
# Found valid PersonGroup: Carlo_Ancelotti
# Found valid PersonGroup: Carlo_Azeglio_Ciampi
# Found valid PersonGroup: Carlton_Baugh
# Found valid PersonGroup: Carlton_Dotson
# Found valid PersonGroup: Carly_Fiorina
# Found valid PersonGroup: Carly_Gullickson
# Found valid PersonGroup: Carl_Levin
# Found valid PersonGroup: Carl_Pope
# Found valid PersonGroup: Carl_Reiner
# Found valid PersonGroup: Carmen_Electra
# Found valid PersonGroup: Carolina_Barco
# Found valid PersonGroup: Carolina_Kluft
# Found valid PersonGroup: Carolina_Moraes
# Found valid PersonGroup: Caroline_Dhavernas
# Found valid PersonGroup: Caroline_Kennedy
# Found valid PersonGroup: Caroline_Link
# Found valid PersonGroup: Carolyn_Dawn_Johnson
# Found valid PersonGroup: Carolyn_Kuhl
# Found valid PersonGroup: Carol_Burnett
# Found valid PersonGroup: Carol_Carmody
# Found valid PersonGroup: Carol_Moseley_Braun
# Found valid PersonGroup: Carol_Niedermayer
# Found valid PersonGroup: Carol_Williams
# Found valid PersonGroup: Carrie-Anne_Moss
# Found valid PersonGroup: Carroll_Weimer
# Found valid PersonGroup: Carson_Daly
# Found valid PersonGroup: Carson_Palmer
# Found valid PersonGroup: Casey_Crowder
# Found valid PersonGroup: Casey_Mears
# Found valid PersonGroup: Cassandra_Heise
# Found valid PersonGroup: Cass_Ballenger
# Found valid PersonGroup: Casy_Preslar
# Found valid PersonGroup: Cate_Blanchett
# Found valid PersonGroup: Catherine_Bell
# Found valid PersonGroup: Catherine_Deneuve
# Found valid PersonGroup: Catherine_Donkers
# Found valid PersonGroup: Catherine_Ndereba
# Found valid PersonGroup: Catherine_Woodard
# Found valid PersonGroup: Catherine_Zeta-Jones
# Found valid PersonGroup: Cathryn_Crawford
# Found valid PersonGroup: Cathy_Chisholm
# Found valid PersonGroup: Cathy_Cunningham
# Found valid PersonGroup: Cathy_Freeman
# Found valid PersonGroup: Catriona_Le_May_Doan
# Found valid PersonGroup: Cecile_de_France
# Found valid PersonGroup: Cecilia_Bolocco
# Found valid PersonGroup: Cecilia_Chang
# Found valid PersonGroup: Cecilia_Cheung
# Found valid PersonGroup: Cedric_Benson
# Found valid PersonGroup: Celia_Cruz
# Found valid PersonGroup: Celine_Dion
# Found valid PersonGroup: Celso_Amorim
# Found valid PersonGroup: Celso_Lafer
# Found valid PersonGroup: Cemil_Cicek
# Found valid PersonGroup: Cesar_Gaviria
# Found valid PersonGroup: Cesar_Maia
# Found valid PersonGroup: Chadha_Gurinder
# Found valid PersonGroup: Chakib_Khelil
# Found valid PersonGroup: Chance_Mock
# Found valid PersonGroup: Chanda_Rubin
# Found valid PersonGroup: Chandrika_Kumaratunga
# Found valid PersonGroup: Chang_Dae-whan
# Found valid PersonGroup: Chang_Jae_On
# Found valid PersonGroup: Chang_Saio-yue
# Found valid PersonGroup: Chang_Sang
# Found valid PersonGroup: Chang_Tso
# Found valid PersonGroup: Chante_Jawan_Mallard
# Found valid PersonGroup: Chan_Choi
# Found valid PersonGroup: Chan_Gailey
# Found valid PersonGroup: Chan_Ho_Park
# Found valid PersonGroup: Charla_Moye
# Found valid PersonGroup: Charlene_Barshefsky
# Found valid PersonGroup: Charles_Bell
# Found valid PersonGroup: Charles_Bronson
# Found valid PersonGroup: Charles_Chandler_IV
# Found valid PersonGroup: Charles_Cope
# Found valid PersonGroup: Charles_Grassley
# Found valid PersonGroup: Charles_Holzner
# Found valid PersonGroup: Charles_Ingram
# Found valid PersonGroup: Charles_Kartman
# Found valid PersonGroup: Charles_Lebois
# Found valid PersonGroup: Charles_Mathews
# Found valid PersonGroup: Charles_Moose
# Found valid PersonGroup: Charles_Pickering
# Found valid PersonGroup: Charles_Pouty
# Found valid PersonGroup: Charles_Richardson
# Found valid PersonGroup: Charles_Rogers
# Found valid PersonGroup: Charles_Schumer
# Found valid PersonGroup: Charles_Tannok
# Found valid PersonGroup: Charles_Taylor
# Found valid PersonGroup: Charley_Armey
# Found valid PersonGroup: Charlie_Coles
# Found valid PersonGroup: Charlie_Deane
# Found valid PersonGroup: Charlie_Garner
# Found valid PersonGroup: Charlie_Hunnam
# Found valid PersonGroup: Charlie_Sheen
# Found valid PersonGroup: Charlie_Williams
# Found valid PersonGroup: Charlie_Zaa
# Found valid PersonGroup: Charlize_Theron
# Found valid PersonGroup: Charlotte_Casiraghi
# Found valid PersonGroup: Charlotte_Chambers
# Found valid PersonGroup: Charlotte_Church
# Found valid PersonGroup: Charlotte_Rampling
# Found valid PersonGroup: Charlton_Heston
# Found valid PersonGroup: Charmaine_Crooks
# Found valid PersonGroup: Chawki_Armali
# Found valid PersonGroup: Cha_Yung-gu
# Found valid PersonGroup: Chea_Sophara
# Found valid PersonGroup: Chelsea_Clinton
# Found valid PersonGroup: Chen_Kaige
# Found valid PersonGroup: Chen_Liang_Yu
# Found valid PersonGroup: Chen_Shui-bian
# Found valid PersonGroup: Chen_Tsai-chin
# Found valid PersonGroup: Cherie_Blair
# Found valid PersonGroup: Cherry_Jones
# Found valid PersonGroup: Cheryl_Ford
# Found valid PersonGroup: Cheryl_Hines
# Found valid PersonGroup: Cheryl_James
# Found valid PersonGroup: Cheryl_Little
# Found valid PersonGroup: Cheryl_Tiegs
# Found valid PersonGroup: Chhouk_Rin
# Found valid PersonGroup: Chick_Hearn
# Found valid PersonGroup: Chin-Feng_Chen
# Found valid PersonGroup: Chin-Hui_Tsao
# Found valid PersonGroup: Chip_Burrus
# Found valid PersonGroup: Chip_Ganassi
# Found valid PersonGroup: Chip_Knight
# Found valid PersonGroup: Chistian_Stahl
# Found valid PersonGroup: Chita_Rivera
# Found valid PersonGroup: Chloe_Sevigny
# Found valid PersonGroup: Choi_Sung-hong
# Found valid PersonGroup: Choi_Yun-yong
# Found valid PersonGroup: Chok_Tong_Goh
# Found valid PersonGroup: Cho_Myung-kyun
# Found valid PersonGroup: Christiane_Wulff
# Found valid PersonGroup: Christian_Bale
# Found valid PersonGroup: Christian_Fittipaldi
# Found valid PersonGroup: Christian_Gimenez
# Found valid PersonGroup: Christian_Lacroix
# Found valid PersonGroup: Christian_Lirette
# Found valid PersonGroup: Christian_Longo
# Found valid PersonGroup: Christian_Malcolm
# Found valid PersonGroup: Christian_Olsson
# Found valid PersonGroup: Christian_Patino
# Found valid PersonGroup: Christian_Von_Wernich
# Found valid PersonGroup: Christian_Wulff
# Found valid PersonGroup: Christina_Aguilera
# Found valid PersonGroup: Christina_Sawaya
# Found valid PersonGroup: Christine_Arron
# Found valid PersonGroup: Christine_Baumgartner
# Found valid PersonGroup: Christine_Ebersole
# Found valid PersonGroup: Christine_Gregoire
# Found valid PersonGroup: Christine_Rau
# Found valid PersonGroup: Christine_Todd_Whitman
# Found valid PersonGroup: Christopher_Amolsch
# Found valid PersonGroup: Christopher_Conyers
# Found valid PersonGroup: Christopher_Matero
# Found valid PersonGroup: Christopher_Patten
# Found valid PersonGroup: Christopher_Reeve
# Found valid PersonGroup: Christopher_Russell
# Found valid PersonGroup: Christopher_Speer
# Found valid PersonGroup: Christopher_Walken
# Found valid PersonGroup: Christopher_Whittle
# Found valid PersonGroup: Christoph_Daum
# Found valid PersonGroup: Christy_Ferer
# Found valid PersonGroup: Christy_Turlington
# Found valid PersonGroup: Chris_Andrews
# Found valid PersonGroup: Chris_Bell
# Found valid PersonGroup: Chris_Byrd
# Found valid PersonGroup: Chris_Cirino
# Found valid PersonGroup: Chris_Claiborne
# Found valid PersonGroup: Chris_Columbus
# Found valid PersonGroup: Chris_Cookson
# Found valid PersonGroup: Chris_Cooper
# Found valid PersonGroup: Chris_Cornell
# Found valid PersonGroup: Chris_Crocker
# Found valid PersonGroup: Chris_Dodd
# Found valid PersonGroup: Chris_Forsyth
# Found valid PersonGroup: Chris_Gratton
# Found valid PersonGroup: Chris_Hernandez
# Found valid PersonGroup: Chris_Klein
# Found valid PersonGroup: Chris_Kolanas
# Found valid PersonGroup: Chris_Matthews
# Found valid PersonGroup: Chris_Moore
# Found valid PersonGroup: Chris_Neil
# Found valid PersonGroup: Chris_Noth
# Found valid PersonGroup: Chris_Penn
# Found valid PersonGroup: Chris_Pronger
# Found valid PersonGroup: Chris_Reitsma
# Found valid PersonGroup: Chris_Rock
# Found valid PersonGroup: Chris_Simon
# Found valid PersonGroup: Chris_Swecker
# Found valid PersonGroup: Chris_Terry
# Found valid PersonGroup: Chris_Thomas
# Found valid PersonGroup: Chris_Tucker
# Found valid PersonGroup: Chris_Whitney
# Found valid PersonGroup: Chuanyun_Li
# Found valid PersonGroup: Chuck_Amato
# Found valid PersonGroup: Chuck_Bednarik
# Found valid PersonGroup: Chuck_Eidson
# Found valid PersonGroup: Chuck_Finley
# Found valid PersonGroup: Chuck_Hagel
# Found valid PersonGroup: Chuck_Woolery
# Found valid PersonGroup: Chuck_Yeager
# Found valid PersonGroup: Chung_Mong-hun
# Found valid PersonGroup: Chung_Mong-joon
# Found valid PersonGroup: Chyung_Dai-chul
# Found valid PersonGroup: Ciaran_Hinds
# Found valid PersonGroup: Cindy_Crawford
# Found valid PersonGroup: Cindy_Klassen
# Found valid PersonGroup: Cindy_Margolis
# Found valid PersonGroup: Cindy_Moll
# Found valid PersonGroup: Cindy_Taylor
# Found valid PersonGroup: Cindy_Zagorski
# Found valid PersonGroup: Ciro_Gomes
# Found valid PersonGroup: Claire_Danes
# Found valid PersonGroup: Claire_De_Gryse
# Found valid PersonGroup: Claire_Hentzen
# Found valid PersonGroup: Claire_Leger
# Found valid PersonGroup: Claire_Tomalin
# Found valid PersonGroup: Clara_Harris
# Found valid PersonGroup: Clare_Latimer
# Found valid PersonGroup: Clare_Short
# Found valid PersonGroup: Clark_Randt
# Found valid PersonGroup: Claudette_Robinson
# Found valid PersonGroup: Claude_Jorda
# Found valid PersonGroup: Claudia_Cardinale
# Found valid PersonGroup: Claudia_Coslovich
# Found valid PersonGroup: Claudia_Pechstein
# Found valid PersonGroup: Claudia_Schiffer
# Found valid PersonGroup: Claudine_Farrell
# Found valid PersonGroup: Claudio_Abbado
# Found valid PersonGroup: Claudio_Lopez
# Found valid PersonGroup: Claudio_Ranieri
# Found valid PersonGroup: Clay_Aiken
# Found valid PersonGroup: Clay_Campbell
# Found valid PersonGroup: Clemente_de_la_Vega
# Found valid PersonGroup: Clifford_Etienne
# Found valid PersonGroup: Clifford_Robinson
# Found valid PersonGroup: Cliff_Ellis
# Found valid PersonGroup: Clint_Eastwood
# Found valid PersonGroup: Clint_Howard
# Found valid PersonGroup: Clint_Lamebear
# Found valid PersonGroup: Clive_Lloyd
# Found valid PersonGroup: Clive_Woodward
# Found valid PersonGroup: Coco_dEste
# Found valid PersonGroup: Coleen_Rowley
# Found valid PersonGroup: Cole_Chapman
# Found valid PersonGroup: Colin_Campbell
# Found valid PersonGroup: Colin_Cowie
# Found valid PersonGroup: Colin_Farrell
# Found valid PersonGroup: Colin_Jackson
# Found valid PersonGroup: Colin_Montgomerie
# Found valid PersonGroup: Colin_Phillips
# Found valid PersonGroup: Colin_Powell
# Found valid PersonGroup: Colin_Prescot
# Found valid PersonGroup: Colleen_Atwood
# Found valid PersonGroup: Colleen_Donovan
# Found valid PersonGroup: Colleen_Jones
# Found valid PersonGroup: Colleen_OClair
# Found valid PersonGroup: Colleen_Ryan
# Found valid PersonGroup: Collis_Temple_III
# Found valid PersonGroup: Columba_Bush
# Found valid PersonGroup: Compay_Segundo
# Found valid PersonGroup: Conan_OBrien
# Found valid PersonGroup: Conchita_Martinez
# Found valid PersonGroup: Condoleezza_Rice
# Found valid PersonGroup: Connie_Chung
# Found valid PersonGroup: Connie_Freydell
# Found valid PersonGroup: Conrad_Black
# Found valid PersonGroup: Constance_Marie
# Found valid PersonGroup: Cora_Cambell
# Found valid PersonGroup: Coretta_Scott_King
# Found valid PersonGroup: Corey_Maggette
# Found valid PersonGroup: Corinna_Harfouch
# Found valid PersonGroup: Corinne_Coman
# Found valid PersonGroup: Cori_Enghusen
# Found valid PersonGroup: Corliss_Williamson
# Found valid PersonGroup: Cosmo_Iacavazzi
# Found valid PersonGroup: Costas_Simitis
# Found valid PersonGroup: Courtney_Cox
# Found valid PersonGroup: Courtney_Love
# Found valid PersonGroup: Craig_Burley
# Found valid PersonGroup: Craig_David
# Found valid PersonGroup: Craig_Doblin
# Found valid PersonGroup: Craig_Fitzgibbon
# Found valid PersonGroup: Craig_MacTavish
# Found valid PersonGroup: Craig_Morgan
# Found valid PersonGroup: Craig_OClair
# Found valid PersonGroup: Craig_Wilson
# Found valid PersonGroup: Crandall_Bowles
# Found valid PersonGroup: Crispin_Glover
# Found valid PersonGroup: Cristiano_da_Matta
# Found valid PersonGroup: Cristian_Barros
# Found valid PersonGroup: Cristina_Fernandez
# Found valid PersonGroup: Cristina_Kirchner
# Found valid PersonGroup: Cristina_Saralegui
# Found valid PersonGroup: Cristina_Torrens_Valero
# Found valid PersonGroup: Cruz_Bustamante
# Found valid PersonGroup: Cuba_Gooding_Jr
# Found valid PersonGroup: Curtis_Joseph
# Found valid PersonGroup: Curtis_Rodriguez
# Found valid PersonGroup: Curtis_Strange
# Found valid PersonGroup: Curt_Weldon
# Found valid PersonGroup: Cyndi_Thompson
# Found valid PersonGroup: Cynthia_Nixon
# Found valid PersonGroup: Cynthia_Rowley
# Found valid PersonGroup: Dagmar_Dunlevy
# Found valid PersonGroup: Daisy_Fuentes
# Found valid PersonGroup: Dai_Bachtiar
# Found valid PersonGroup: Dai_Chul_Chyung
# Found valid PersonGroup: Daja_Bedanova
# Found valid PersonGroup: Dalai_Lama
# Found valid PersonGroup: Dale_Bosworth
# Found valid PersonGroup: Dale_Earnhardt
# Found valid PersonGroup: Dale_Earnhardt_Jr
# Found valid PersonGroup: Dalia_Rabin-Pelosoff
# Found valid PersonGroup: Damarius_Bilbo
# Found valid PersonGroup: Damon_Dash
# Found valid PersonGroup: Damon_Stoudamire
# Found valid PersonGroup: Damon_van_Dam
# Found valid PersonGroup: Dana_Vollmer
# Found valid PersonGroup: DAngelo_Jimenez
# Found valid PersonGroup: Daniela_Cicarelli
# Found valid PersonGroup: Daniela_Hantuchova
# Found valid PersonGroup: Daniele_Bergamin
# Found valid PersonGroup: Daniele_Hypolito
# Found valid PersonGroup: Daniele_Nardello
# Found valid PersonGroup: Danielle_Spencer
# Found valid PersonGroup: Daniell_Sunjata
# Found valid PersonGroup: Daniel_Barenboim
# Found valid PersonGroup: Daniel_Bruehl
# Found valid PersonGroup: Daniel_Chin
# Found valid PersonGroup: Daniel_Coats
# Found valid PersonGroup: Daniel_Comisso_Urdaneta
# Found valid PersonGroup: Daniel_Darnell
# Found valid PersonGroup: Daniel_Day-Lewis
# Found valid PersonGroup: Daniel_Kurtzer
# Found valid PersonGroup: Daniel_Montenegro
# Found valid PersonGroup: Daniel_Montgomery
# Found valid PersonGroup: Daniel_Ortega
# Found valid PersonGroup: Daniel_Osorno
# Found valid PersonGroup: Daniel_Patrick_Moynihan
# Found valid PersonGroup: Daniel_Pearl
# Found valid PersonGroup: Daniel_Radcliffe
# Found valid PersonGroup: Daniel_Rouse
# Found valid PersonGroup: Daniel_Scioli
# Found valid PersonGroup: Daniel_Zelman
# Found valid PersonGroup: Danis_Tanovic
# Found valid PersonGroup: Danny_Ainge
# Found valid PersonGroup: Danny_Avalon
# Found valid PersonGroup: Danny_Elfman
# Found valid PersonGroup: Danny_Glover
# Found valid PersonGroup: Danny_Green
# Found valid PersonGroup: Danny_Morgan
# Found valid PersonGroup: Dany_Heatley
# Found valid PersonGroup: Dan_Ackroyd
# Found valid PersonGroup: Dan_Bartlett
# Found valid PersonGroup: Dan_Boyle
# Found valid PersonGroup: Dan_Bylsma
# Found valid PersonGroup: Dan_Dickau
# Found valid PersonGroup: Dan_Duquette
# Found valid PersonGroup: Dan_Guerrero
# Found valid PersonGroup: Dan_Kellner
# Found valid PersonGroup: Dan_LaCoutre
# Found valid PersonGroup: Dan_Monson
# Found valid PersonGroup: Dan_Morales
# Found valid PersonGroup: Dan_Prinster
# Found valid PersonGroup: Dan_Quayle
# Found valid PersonGroup: Dan_Reeves
# Found valid PersonGroup: Dan_Snyder
# Found valid PersonGroup: Dan_Wheldon
# Found valid PersonGroup: Darcy_Regier
# Found valid PersonGroup: Darin_Erstad
# Found valid PersonGroup: Dario_Camuffo
# Found valid PersonGroup: Dario_Franchitti
# Found valid PersonGroup: Dariusz_Michalczewski
# Found valid PersonGroup: Darko_Milicic
# Found valid PersonGroup: Darla_Moore
# Found valid PersonGroup: Darlene_Garrettson
# Found valid PersonGroup: Darrell_Dickey
# Found valid PersonGroup: Darrell_Issa
# Found valid PersonGroup: Darrell_Porter
# Found valid PersonGroup: Darrell_Royal
# Found valid PersonGroup: Darren_Campel
# Found valid PersonGroup: Darren_Clarke
# Found valid PersonGroup: Darryl_McDaniels
# Found valid PersonGroup: Darryl_Stingley
# Found valid PersonGroup: Darvis_Patton
# Found valid PersonGroup: Daryl_Hannah
# Found valid PersonGroup: Daryl_Jones
# Found valid PersonGroup: Daryl_Parks
# Found valid PersonGroup: Daryl_Sabara
# Found valid PersonGroup: Daryl_Smith
# Found valid PersonGroup: Davey_Johnson
# Found valid PersonGroup: Dave_Barr
# Found valid PersonGroup: Dave_Campo
# Found valid PersonGroup: Dave_Johnson
# Found valid PersonGroup: Dave_Lewis
# Found valid PersonGroup: Dave_Matthews
# Found valid PersonGroup: Dave_McGinnis
# Found valid PersonGroup: Dave_McNally
# Found valid PersonGroup: Dave_McNealey
# Found valid PersonGroup: Dave_Odom
# Found valid PersonGroup: Dave_Potter
# Found valid PersonGroup: Dave_Ragone
# Found valid PersonGroup: Dave_Robertson
# Found valid PersonGroup: Dave_Tucker
# Found valid PersonGroup: Dave_Wannstedt
# Found valid PersonGroup: Dave_Williams
# Found valid PersonGroup: David_Alpay
# Found valid PersonGroup: David_Anderson
# Found valid PersonGroup: David_Arquette
# Found valid PersonGroup: David_Ballantyne
# Found valid PersonGroup: David_Beckham
# Found valid PersonGroup: David_Bell
# Found valid PersonGroup: David_Bisbal
# Found valid PersonGroup: David_Blaine
# Found valid PersonGroup: David_Bowie
# ...
# Found valid PersonGroup: Thomas_Scavone
# Found valid PersonGroup: Thomas_Stewart
# Found valid PersonGroup: Thomas_Ulrich
# Found valid PersonGroup: Thomas_Van_Essen
# Found valid PersonGroup: Thomas_Watjen
# Found valid PersonGroup: Thomas_Weston
# Found valid PersonGroup: Thomas_Wilkens
# Found valid PersonGroup: Thomas_Wyman
# Found valid PersonGroup: Thor_Pedersen
# Found valid PersonGroup: Tiago_Splitter
# Found valid PersonGroup: Tian_Liang
# Found valid PersonGroup: Tian_Zhuang_Zhuang
# Found valid PersonGroup: Tia_Mowry
# Found valid PersonGroup: Tiffany_Limos
# Found valid PersonGroup: Tiger_Woods
# Found valid PersonGroup: Timbul_Silaen
# Found valid PersonGroup: Timothy_Coughlin
# Found valid PersonGroup: Timothy_Goebel
# Found valid PersonGroup: Timothy_McVeigh
# Found valid PersonGroup: Timothy_Rigas
# Found valid PersonGroup: Timothy_Wirth
# Found valid PersonGroup: Tim_Allen
# Found valid PersonGroup: Tim_Blake_Nelson
# Found valid PersonGroup: Tim_Chapman
# Found valid PersonGroup: Tim_Conway
# Found valid PersonGroup: Tim_Curley
# Found valid PersonGroup: Tim_Curry
# Found valid PersonGroup: Tim_Duncan
# Found valid PersonGroup: Tim_Floyd
# Found valid PersonGroup: Tim_Henman
# Found valid PersonGroup: Tim_Howard
# Found valid PersonGroup: Tim_Jones
# Found valid PersonGroup: Tim_Lobinger
# Found valid PersonGroup: Tim_Lopes
# Found valid PersonGroup: Tim_Matheson
# Found valid PersonGroup: Tim_Norbeck
# Found valid PersonGroup: Tim_Pawlenty
# Found valid PersonGroup: Tim_Robbins
# Found valid PersonGroup: Tim_Salmon
# Found valid PersonGroup: Tim_Welsh
# Found valid PersonGroup: Tina_Andrews
# Found valid PersonGroup: Tina_Brown
# Found valid PersonGroup: Tina_Conner
# Found valid PersonGroup: Tina_Fey
# Found valid PersonGroup: Tina_Pisnik
# Found valid PersonGroup: Tina_Sinatra
# Found valid PersonGroup: Tino_Martinez
# Found valid PersonGroup: Tippi_Hedren
# Found valid PersonGroup: Tirunesh_Dibaba
# Found valid PersonGroup: TJ_Ford
# Found valid PersonGroup: Toby_Keith
# Found valid PersonGroup: Tocker_Pudwill
# Found valid PersonGroup: Todd_Haynes
# Found valid PersonGroup: Todd_MacCulloch
# Found valid PersonGroup: Todd_Parrott
# Found valid PersonGroup: Todd_Petit
# Found valid PersonGroup: Todd_Reid
# Found valid PersonGroup: Todd_Robbins
# Found valid PersonGroup: Todd_Wike
# Found valid PersonGroup: Tomas_Enge
# Found valid PersonGroup: Tomas_Malik
# Found valid PersonGroup: Tommy_Amaker
# Found valid PersonGroup: Tommy_Franks
# Found valid PersonGroup: Tommy_Haas
# Found valid PersonGroup: Tommy_Lasorda
# Found valid PersonGroup: Tommy_Lewis
# Found valid PersonGroup: Tommy_Maddox
# Found valid PersonGroup: Tommy_Robredo
# Found valid PersonGroup: Tommy_Shane_Steiner
# Found valid PersonGroup: Tommy_Thompson
# Found valid PersonGroup: Tommy_Tubberville
# Found valid PersonGroup: Tomoko_Hagiwara
# Found valid PersonGroup: Tomomi_Morita
# Found valid PersonGroup: Tom_Amstutz
# Found valid PersonGroup: Tom_Brady
# Found valid PersonGroup: Tom_Brennan
# Found valid PersonGroup: Tom_Christerson
# Found valid PersonGroup: Tom_Coughlin
# Found valid PersonGroup: Tom_Coverdale
# Found valid PersonGroup: Tom_Craddick
# Found valid PersonGroup: Tom_Crean
# Found valid PersonGroup: Tom_Cruise
# Found valid PersonGroup: Tom_Curley
# Found valid PersonGroup: Tom_Daschle
# Found valid PersonGroup: Tom_DeLay
# Found valid PersonGroup: Tom_Foy
# Found valid PersonGroup: Tom_Gamboa
# Found valid PersonGroup: Tom_Glavine
# Found valid PersonGroup: Tom_Hanks
# Found valid PersonGroup: Tom_Hanusik
# Found valid PersonGroup: Tom_Harkin
# Found valid PersonGroup: Tom_Izzo
# Found valid PersonGroup: Tom_Jones
# Found valid PersonGroup: Tom_Kelly
# Found valid PersonGroup: Tom_Koenigs
# Found valid PersonGroup: Tom_Lantos
# Found valid PersonGroup: Tom_McClintock
# Found valid PersonGroup: Tom_Miller
# Found valid PersonGroup: Tom_Moss
# Found valid PersonGroup: Tom_OBrien
# Found valid PersonGroup: Tom_Osborne
# Found valid PersonGroup: Tom_Poston
# Found valid PersonGroup: Tom_Reilly
# Found valid PersonGroup: Tom_Ridge
# Found valid PersonGroup: Tom_Rouen
# Found valid PersonGroup: Tom_Schnackenberg
# Found valid PersonGroup: Tom_Scully
# Found valid PersonGroup: Tom_Sizemore
# Found valid PersonGroup: Tom_Smothers
# Found valid PersonGroup: Tom_Tunney
# Found valid PersonGroup: Tom_Vilsack
# Found valid PersonGroup: Tom_Watson
# Found valid PersonGroup: Tom_Welch
# Found valid PersonGroup: Tonga
# Found valid PersonGroup: Tonino_Guerra
# Found valid PersonGroup: Toni_Braxton
# Found valid PersonGroup: Toni_Jennings
# Found valid PersonGroup: Tono_Suratman
# Found valid PersonGroup: Tonya_Payne
# Found valid PersonGroup: Tony_Bennett
# Found valid PersonGroup: Tony_Blair
# Found valid PersonGroup: Tony_Clement
# Found valid PersonGroup: Tony_Cummo
# Found valid PersonGroup: Tony_Curtis
# Found valid PersonGroup: Tony_Elias
# Found valid PersonGroup: Tony_Fernandes
# Found valid PersonGroup: Tony_LaRussa
# Found valid PersonGroup: Tony_Parker
# Found valid PersonGroup: Tony_Shalhoub
# Found valid PersonGroup: Tony_Stewart
# Found valid PersonGroup: Tora_Takagi
# Found valid PersonGroup: Tori_Amos
# Found valid PersonGroup: Torri_Edwards
# Found valid PersonGroup: Toshihiko_Fukui
# Found valid PersonGroup: Toshimitsu_Motegi
# Found valid PersonGroup: Toshi_Izawa
# Found valid PersonGroup: Toutai_Kefu
# Found valid PersonGroup: Tracee_Ellis_Ross
# Found valid PersonGroup: Tracee_Treadwell
# Found valid PersonGroup: Tracy_McGrady
# Found valid PersonGroup: Tracy_Wyle
# Found valid PersonGroup: Travis_Rudolph
# Found valid PersonGroup: Trent_Lott
# Found valid PersonGroup: Trevor_McDonald
# Found valid PersonGroup: Trevor_Watson
# Found valid PersonGroup: Trisha_Meili
# Found valid PersonGroup: Tristan_Gretzky
# Found valid PersonGroup: Trista_Rehn
# Found valid PersonGroup: Troy_Aikman
# Found valid PersonGroup: Troy_Garity
# Found valid PersonGroup: Troy_Hudson
# Found valid PersonGroup: Troy_Jenkins
# Found valid PersonGroup: Troy_Polamalu
# Found valid PersonGroup: Trudi_Lacey
# Found valid PersonGroup: Tsutomu_Takebe
# Found valid PersonGroup: Tubby_Smith
# Found valid PersonGroup: Tuncay_Sanli
# Found valid PersonGroup: Tung_Chee-hwa
# Found valid PersonGroup: Turner_Gill
# Found valid PersonGroup: Turner_Stevenson
# Found valid PersonGroup: Tyler_Grillo
# Found valid PersonGroup: Tyler_Hamilton
# Found valid PersonGroup: Tyra_Banks
# Found valid PersonGroup: Tyrone_Medley
# Found valid PersonGroup: Tyron_Garner
# Found valid PersonGroup: Ty_Votaw
# Found valid PersonGroup: Tzipora_Obziler
# Found valid PersonGroup: T_Boone_Pickens
# Found valid PersonGroup: Uday_Hussein
# Found valid PersonGroup: Ulrich_Kueperkoch
# Found valid PersonGroup: Uma_Thurman
# Found valid PersonGroup: Uri_Lopolianski
# Found valid PersonGroup: Urmila_Matondkar
# Found valid PersonGroup: Uthai_Pimchaichon
# Found valid PersonGroup: Uzi_Even
# Found valid PersonGroup: Uzi_Landau
# Found valid PersonGroup: Vaclav_Havel
# Found valid PersonGroup: Vaclav_Klaus
# Found valid PersonGroup: Vadim_Devyatovskiy
# Found valid PersonGroup: Vadim_Strogalev
# Found valid PersonGroup: Vagit_Alekperov
# Found valid PersonGroup: Valdas_Adamkus
# Found valid PersonGroup: Valentina_Cervi
# Found valid PersonGroup: Valentina_Tereshkova
# Found valid PersonGroup: Valentino_Rossi
# Found valid PersonGroup: Valerie_Harper
# Found valid PersonGroup: Valerie_Thwaites
# Found valid PersonGroup: Valeri_Bure
# Found valid PersonGroup: Valery_Giscard_dEstaing
# Found valid PersonGroup: Valorie_Brabazon
# Found valid PersonGroup: Val_Ackerman
# Found valid PersonGroup: Vanessa_Incontrada
# Found valid PersonGroup: Vanessa_Laine
# Found valid PersonGroup: Vanessa_Redgrave
# Found valid PersonGroup: Vanessa_Williams
# Found valid PersonGroup: Van_Hilley
# Found valid PersonGroup: Vassilis_Xiros
# Found valid PersonGroup: Vecdi_Gonul
# Found valid PersonGroup: Venus_Williams
# Found valid PersonGroup: Vernon_Forrest
# Found valid PersonGroup: Veronica_Lake
# Found valid PersonGroup: Viara_Vike-Freiberga
# Found valid PersonGroup: Vicente_Fernandez
# Found valid PersonGroup: Vicente_Fox
# Found valid PersonGroup: Vicente_Fox_de_la_Concha
# Found valid PersonGroup: Vicki_Zhao_Wei
# Found valid PersonGroup: Victoria_Beckham
# Found valid PersonGroup: Victoria_Clarke
# Found valid PersonGroup: Victor_Garber
# Found valid PersonGroup: Victor_Hanescu
# Found valid PersonGroup: Victor_Kraatz
# Found valid PersonGroup: Vidar_Helgesen
# Found valid PersonGroup: Vijay_Nambiar
# Found valid PersonGroup: Viktor_Yushchenko
# Found valid PersonGroup: Vincent_Brooks
# Found valid PersonGroup: Vincent_Cianci_Jr
# Found valid PersonGroup: Vincent_Gallo
# Found valid PersonGroup: Vincent_Sombrotto
# Found valid PersonGroup: Vincent_Spadea
# Found valid PersonGroup: Vince_Carter
# Found valid PersonGroup: Vince_Dooley
# Found valid PersonGroup: Vince_Gill
# Found valid PersonGroup: Vince_Vaughan
# Found valid PersonGroup: Vinnie_Jones
# Found valid PersonGroup: Vin_Diesel
# Found valid PersonGroup: Viola_Davis
# Found valid PersonGroup: Virgina_Ruano_Pascal
# Found valid PersonGroup: Vitali_Klitschko
# Found valid PersonGroup: Vivica_Fox
# Found valid PersonGroup: Vladimiro_Montesinos
# Found valid PersonGroup: Vladimir_Golovlyov
# Found valid PersonGroup: Vladimir_Meciar
# Found valid PersonGroup: Vladimir_Putin
# Found valid PersonGroup: Vladimir_Spidla
# Found valid PersonGroup: Vladimir_Ustinov
# Found valid PersonGroup: Vladimir_Voltchkov
# Found valid PersonGroup: Vojislav_Kostunica
# Found valid PersonGroup: Vojislav_Seselj
# Found valid PersonGroup: Vyacheslav_Fetisov
# Found valid PersonGroup: Vytas_Danelius
# Found valid PersonGroup: Walid_Al-Awadi
# Found valid PersonGroup: Wallace_Capel
# Found valid PersonGroup: Wally_Szczerbiak
# Found valid PersonGroup: Walter_Annenberg
# Found valid PersonGroup: Walter_Mondale
# Found valid PersonGroup: Walter_Woods
# Found valid PersonGroup: Walt_Harris
# Found valid PersonGroup: Wanda_de_la_Jesus
# Found valid PersonGroup: Wanda_Ilene_Barzee
# Found valid PersonGroup: Wang_Fei
# Found valid PersonGroup: Wang_Hailan
# Found valid PersonGroup: Wang_Nan
# Found valid PersonGroup: Wang_Yi
# Found valid PersonGroup: Wang_Yingfan
# Found valid PersonGroup: Wan_Yanhai
# Found valid PersonGroup: Ward_Cuff
# Found valid PersonGroup: Warren_Beatty
# Found valid PersonGroup: Warren_Buffett
# Found valid PersonGroup: Warren_Granados
# Found valid PersonGroup: Warren_Truss
# Found valid PersonGroup: Wayne_Allard
# Found valid PersonGroup: Wayne_Brady
# Found valid PersonGroup: Wayne_Ferreira
# Found valid PersonGroup: Wayne_Gretzky
# Found valid PersonGroup: Wayne_Newton
# Found valid PersonGroup: Wei_Wu
# Found valid PersonGroup: Wendell_Bryant
# Found valid PersonGroup: Wendy_Kennedy
# Found valid PersonGroup: Wendy_Selig
# Found valid PersonGroup: Wen_Ho_Lee
# Found valid PersonGroup: Wen_Jiabao
# Found valid PersonGroup: Werner_Schlager
# Found valid PersonGroup: Wesley_Clark
# Found valid PersonGroup: Wes_Craven
# Found valid PersonGroup: Whoopi_Goldberg
# Found valid PersonGroup: Wilbert_Elki_Meza_Majino
# Found valid PersonGroup: Wilbert_Foy
# Found valid PersonGroup: Wilfredo_Moreno
# Found valid PersonGroup: William_Bratton
# Found valid PersonGroup: William_Bulger
# Found valid PersonGroup: William_Burns
# Found valid PersonGroup: William_Cocksedge
# Found valid PersonGroup: William_Delahunt
# Found valid PersonGroup: William_Donaldson
# Found valid PersonGroup: William_Ford_Jr
# Found valid PersonGroup: William_Genego
# Found valid PersonGroup: William_Harrison
# Found valid PersonGroup: William_Hochul
# Found valid PersonGroup: William_Hurt
# Found valid PersonGroup: William_Hyde
# Found valid PersonGroup: William_Jackson
# Found valid PersonGroup: William_Joppy
# Found valid PersonGroup: William_Macy
# Found valid PersonGroup: William_Martin
# Found valid PersonGroup: William_McDonough
# Found valid PersonGroup: William_Morrow
# Found valid PersonGroup: William_Murabito
# Found valid PersonGroup: William_Nessen
# Found valid PersonGroup: William_Overlin
# Found valid PersonGroup: William_Perry
# Found valid PersonGroup: William_Pryor_Jr
# Found valid PersonGroup: William_Ragland
# Found valid PersonGroup: William_Rehnquist
# Found valid PersonGroup: William_Rosenberg
# Found valid PersonGroup: William_Shatner
# Found valid PersonGroup: William_Swor
# Found valid PersonGroup: William_Umbach
# Found valid PersonGroup: William_Webster
# Found valid PersonGroup: Willie_Nelson
# Found valid PersonGroup: Willie_Wilson
# Found valid PersonGroup: Willis_Roberts
# Found valid PersonGroup: Will_Ferrell
# Found valid PersonGroup: Will_Ofenheusle
# Found valid PersonGroup: Will_Self
# Found valid PersonGroup: Will_Smith
# Found valid PersonGroup: Will_Young
# Found valid PersonGroup: Wilma_McNabb
# Found valid PersonGroup: Wilson_Alvarez
# Found valid PersonGroup: Wilton_Gregory
# Found valid PersonGroup: Wim_Duisenberg
# Found valid PersonGroup: Winona_Ryder
# Found valid PersonGroup: Winston_Churchill
# Found valid PersonGroup: Win_Aung
# Found valid PersonGroup: Wolfgang_Becker
# Found valid PersonGroup: Wolfgang_Clement
# Found valid PersonGroup: Wolfgang_Schneiderhan
# Found valid PersonGroup: Wolfgang_Schuessel
# Found valid PersonGroup: Wolfgang_Schwarz
# Found valid PersonGroup: Woodrow_Stanley
# Found valid PersonGroup: Woody_Allen
# Found valid PersonGroup: Wu_Peng
# Found valid PersonGroup: Wu_Yi
# Found valid PersonGroup: Wycliffe_Grousbeck
# Found valid PersonGroup: Xanana_Gusmao
# Found valid PersonGroup: Xavier_Malisse
# Found valid PersonGroup: Xiang_Huaicheng
# Found valid PersonGroup: Xiang_Liu
# Found valid PersonGroup: Xiang_Xu
# Found valid PersonGroup: Ximena_Bohorquez
# Found valid PersonGroup: Yale_Kamisar
# Found valid PersonGroup: Yana_Klochkova
# Found valid PersonGroup: Yang_Hee_Kim
# Found valid PersonGroup: Yang_Jianli
# Found valid PersonGroup: Yang_Pao-yu
# Found valid PersonGroup: Yannos_Papantoniou
# Found valid PersonGroup: Yann_Martel
# Found valid PersonGroup: Yao_Ming
# Found valid PersonGroup: Yasar_Yakis
# Found valid PersonGroup: Yasein_Taher
# Found valid PersonGroup: Yashwant_Sinha
# Found valid PersonGroup: Yasser_Arafat
# Found valid PersonGroup: Yasushi_Akashi
# Found valid PersonGroup: Yasushi_Chimura
# Found valid PersonGroup: Yekaterina_Guseva
# Found valid PersonGroup: Yevgeny_Kafelnikov
# Found valid PersonGroup: Yingfan_Wang
# Found valid PersonGroup: Yishan_Zhang
# Found valid PersonGroup: Yoelbi_Quesada
# Found valid PersonGroup: Yogi_Berra
# Found valid PersonGroup: Yoko_Ono
# Found valid PersonGroup: Yolanda_King
# Found valid PersonGroup: Yoon_Jeong_Cho
# Found valid PersonGroup: Yoon_Jin-Sik
# Found valid PersonGroup: Yoon_Won-Sik
# Found valid PersonGroup: Yoon_Young-kwan
# Found valid PersonGroup: Yoo_Jay-Kun
# Found valid PersonGroup: Yoriko_Kawaguchi
# Found valid PersonGroup: Yory_Boy_Campas
# Found valid PersonGroup: Yoshiyuki_Kamei
# Found valid PersonGroup: Yossi_Beilin
# Found valid PersonGroup: Young_Kim
# Found valid PersonGroup: Yukiko_Okudo
# Found valid PersonGroup: Yukio_Hatoyama
# Found valid PersonGroup: Yuri_Fedotov
# Found valid PersonGroup: Yuri_Luzhkov
# Found valid PersonGroup: Yuri_Malenchenko
# Found valid PersonGroup: Yusaku_Miyazato
# Found valid PersonGroup: Yusuf_Misbac
# Found valid PersonGroup: Yuvraj_Singh
# Found valid PersonGroup: Yu_Shyi-kun
# Found valid PersonGroup: Yves_Brodeur
# Found valid PersonGroup: Zach_Parise
# Found valid PersonGroup: Zach_Pillar
# Found valid PersonGroup: Zach_Safrin
# Found valid PersonGroup: Zafarullah_Khan_Jamali
# Found valid PersonGroup: Zahir_Shah
# Found valid PersonGroup: Zaini_Abdullah
# Found valid PersonGroup: Zakia_Hakki
# Found valid PersonGroup: Zalmay_Khalilzad
# Found valid PersonGroup: Zarai_Toledo
# Found valid PersonGroup: Zara_Akhmadova
# Found valid PersonGroup: Zavad_Zarif
# Found valid PersonGroup: Zdravko_Mucic
# Found valid PersonGroup: Zeljko_Rebraca
# Found valid PersonGroup: Zelma_Novelo
# Found valid PersonGroup: Zeng_Qinghong
# Found valid PersonGroup: Zhang_Wenkang
# Found valid PersonGroup: Zhang_Yimou
# Found valid PersonGroup: Zhang_Ziyi
# Found valid PersonGroup: Zhong_Nanshan
# Found valid PersonGroup: Zhu_Rongji
# Found valid PersonGroup: Zico
# Found valid PersonGroup: Zinedine_Zidane
# Found valid PersonGroup: Ziwang_Xu
# Found valid PersonGroup: Zoe_Ball
# Found valid PersonGroup: Zoran_Djindjic
# Found valid PersonGroup: Zorica_Radovic
# Found valid PersonGroup: Zulfiqar_Ahmed
# Found valid PersonGroup: Zumrati_Juma
# Found valid PersonGroup: Zurab_Tsereteli
# Found valid PersonGroup: Zydrunas_Ilgauskas
# Total PersonGroup: 5749
